# %%
print("ok")
# Out:
# ok

# %%
import os

os.chdir("..")
os.getcwd()
# Out:
# 'c:\\Users\\PC\\Desktop\\Allproject\\Zuba_agents\\realbackend'

# %%
from app.graphs.content_graph import build_content_graph

graph = build_content_graph()


result = graph.invoke({
    "topic": "Learning LangGraph",
    "platform": "X",
    "ideas": []
})


print(result)
# Out:
# Direct use of automatic function calling (AFC) in Models.generate_content is not recommended. Instead, we recommend to use AFC in Chat.send_message. Similarly, direct use of AFC in Models.generate_content_stream is not recommended. Instead, we recommend to use AFC in Chat.send_message_stream.
# {'topic': 'Learning LangGraph', 'platform': 'X', 'ideas': [[{'type': 'text', 'text': 'Here are 5 highly specific, high-engagement content ideas tailored for X to help you build authority in the AI engineering space while documenting your LangGraph learning journey.\n\n---\n\n### Idea 1: The Architectural Shift (Technical Explanation / Text + Code)\n* **Title:** "Why your LLM agents get stuck in loops (and how LangGraph’s state machine fixes it)"\n* **The Core Angle:** A technical breakdown comparing traditional linear LLM chains (like basic LangChain or sequential API calls) to LangGraph\'s cyclic graph structure. You’ll explain how LangGraph uses a centralized "State" to allow agents to backtrack, self-correct, and loop until a task is actually finished.\n* **Why someone would care:** Every AI engineer building agents has experienced the frustration of an LLM getting stuck in an infinite loop or losing track of its goal. Explaining the *mental shift* from "chains" to "state machines" solves a major conceptual bottleneck for developers trying to build reliable agents.\n\n### Idea 2: The Practical "Build in Public" Show-and-Tell (Interactive / Code)\n* **Title:** "How to build a \'Human-in-the-Loop\' safety switch in LangGraph under 50 lines of code"\n* **The Core Angle:** Share a code snippet (or a mini-Github repo link) showing how to use LangGraph’s `interrupt_before` feature. This feature pauses an agent\'s execution (e.g., before sending an email or executing a database write) to wait for human approval.\n* **Why someone would care:** "Human-in-the-loop" (HITL) is the gold standard for production-grade AI agents. Developers want to deploy agents but are terrified of them hallucinating bad actions. Showing them a concrete, simple implementation of a safety switch is highly shareable and immediately useful.\n\n### Idea 3: The Framework Showdown (AI Opinion / Industry Development)\n* **Title:** "LangGraph vs. CrewAI vs. AutoGen: How to choose the right agent framework for your next project"\n* **The Core Angle:** A nuanced, objective comparison of the current agent framework landscape. Contrast CrewAI (high-level, role-play focused) and AutoGen (conversation-driven) with LangGraph (low-level, highly customizable, graph-based). \n* **Why someone would care:** AI engineers and tech leads are suffering from "framework fatigue." They don\'t want to waste weeks building on the wrong stack. Giving them a clear decision matrix (e.g., "Choose CrewAI if you want quick prototypes; choose LangGraph if you need deterministic control over complex workflows") establishes you as a practical, unbiased industry expert.\n\n### Idea 4: The "Demystifying" Deep-Dive (Technical Explanation / Thread)\n* **Title:** "Demystifying LangGraph State: How to pass data between AI agents without losing your mind"\n* **The Core Angle:** A step-by-step visual thread explaining how LangGraph\'s `State` works. Use a simple analogy (like a shared Google Doc that agents take turns editing) to explain how nodes read from and write to a shared `TypedDict`, and how reducers handle state updates.\n* **Why someone would care:** State management is notoriously the hardest part of learning LangGraph. Beginners get lost in how data flows between nodes. A clear, simplified explanation with a basic diagram or ASCII art will get bookmarked and retweeted by developers struggling with the official documentation.\n\n### Idea 5: Advanced Multi-Agent Blueprint (AI Engineering / Architecture)\n* **Title:** "The \'Supervisor-Worker\' pattern: How to orchestrate 3 specialized AI agents using LangGraph"\n* **The Core Angle:** Share an architectural blueprint of a multi-agent system. Explain how one "Supervisor" agent receives a user prompt, breaks it down, routes tasks to specialized "Worker" agents (e.g., a Researcher, a Writer, and a Coder), and aggregates the final result.\n* **Why someone would care:** Single agents fail at complex tasks. The industry is rapidly moving toward mu ...
