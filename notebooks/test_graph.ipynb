# %%
print("ok")
# Out:
# ok

# %%
import os

os.chdir("..")
os.getcwd()
# Out:
# 'c:\\Users\\PC\\Desktop\\Allproject\\Zuba_agents\\realbackend'

# %%
from app.graphs.content_graph import build_content_graph

graph = build_content_graph()

png = graph.get_graph().draw_mermaid_png()

with open("content_graph3.png", "wb") as f:
    f.write(png)

print("Graph saved to content_graph3.png")
# Out:
# Graph saved to content_graph3.png
